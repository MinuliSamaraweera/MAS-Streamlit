# %% [markdown]
# # Future predictions for next month of forecast

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np

# Load the data
df = pd.read_csv('worker_defect_details.csv')

# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Set Date as index
df.set_index('Date', inplace=True)

defect_types = ['Run_Off_D1', 'Open_Seam_D2', 'SPI_Errors_D3', 'High_Low_D4']

# Plotting time series for each defect type
plt.figure(figsize=(14, 10))
for i, defect_type in enumerate(defect_types, 1):
    plt.subplot(len(defect_types), 1, i)
    plt.plot(df.index, df[defect_type], marker='o', linestyle='-', color='red')  # Red color
    plt.title(f'Previous data plot for {defect_type}')
    plt.xlabel('Date')
    plt.ylabel(f'{defect_type} Count')
    plt.grid(True)
plt.tight_layout()
plt.show()

# Calculate summary statistics for each defect type
summary_stats = df[defect_types].agg(['mean', 'sum']).transpose()

# Determine high and low defect types
high_defect_type = summary_stats.idxmax()['mean']
low_defect_type = summary_stats.idxmin()['mean']

print(f"High defect type: {high_defect_type}")
print(f"Low defect type: {low_defect_type}")

print()

# Train ARIMA models and make forecasts for each defect type
forecast_steps = 4  # Number of steps to forecast into the future

def train_arima_model(data, order=(1, 1, 1), steps=4):
    model = ARIMA(data, order=order)
    model_fit = model.fit()
    forecast = model_fit.forecast(steps=steps)
    return model_fit, forecast

def calculate_rmse(observed, forecast):
    mse = mean_squared_error(observed, forecast)
    rmse = np.sqrt(mse)
    return rmse

for defect_type in defect_types:
    print(f"Training ARIMA model for {defect_type}...")
    model_fit, forecast = train_arima_model(df[defect_type], steps=forecast_steps)

    # Calculate RMSE
    rmse = calculate_rmse(df[defect_type][-forecast_steps:], forecast)
    print(f"RMSE for {defect_type}: {rmse}")

    # Plotting the results
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df[defect_type], label='Observed', color='green')  # Blue color for observed
    future_dates = pd.date_range(start=df.index[-1], periods=forecast_steps + 1, freq='B')[1:]
    plt.plot(future_dates, forecast, label='Forecast', linestyle='--', marker='o', color='purple')  # Purple color for forecast
    plt.title(f'Future forecast for {defect_type}')
    plt.xlabel('Date')
    plt.ylabel(f'{defect_type} Count')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print model summary
    print(model_fit.summary())
# Out:
# /var/folders/68/8_7nlx1973v1qqcz0zq5wt8m0000gn/T/ipykernel_989/2041772493.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])
# High defect type: Open_Seam_D2
# Low defect type: Run_Off_D1
#
# Training ARIMA model for Run_Off_D1...
# RMSE for Run_Off_D1: 2.378473403078292
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Run_Off_D1   No. Observations:                   23
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -50.594
# Date:                Fri, 21 Jun 2024   AIC                            107.189
# Time:                        20:35:53   BIC                            110.462
# Sample:                    01-01-2024   HQIC                           107.960
#                          - 01-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0955      0.336     -0.284      0.776      -0.754       0.563
# ma.L1         -0.9996     67.533     -0.015      0.988    -133.363     131.364
# sigma2         5.0089    335.982      0.015      0.988    -653.505     663.522
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.32   Jarque-Bera (JB):                 2.08
# Prob(Q):                              0.57   Prob(JB):                         0.35
# Heteroskedasticity (H):               1.41   Skew:                             0.15
# Prob(H) (two-sided):                  0.66   Kurtosis:                         1.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training ARIMA model for Open_Seam_D2...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# RMSE for Open_Seam_D2: 1.6838481230234215
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Open_Seam_D2   No. Observations:                   23
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -45.932
# Date:                Fri, 21 Jun 2024   AIC                             97.864
# Time:                        20:35:53   BIC                            101.137
# Sample:                    01-01-2024   HQIC                            98.635
#                          - 01-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0662      0.304     -0.218      0.827      -0.662       0.529
# ma.L1         -0.8222      0.218     -3.769      0.000      -1.250      -0.395
# sigma2         3.6020      1.859      1.937      0.053      -0.042       7.246
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):                 1.39
# Prob(Q):                              0.69   Prob(JB):                         0.50
# Heteroskedasticity (H):               1.12   Skew:                            -0.49
# Prob(H) (two-sided):                  0.88   Kurtosis:                         2.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training ARIMA model for SPI_Errors_D3...
# RMSE for SPI_Errors_D3: 2.3353810500327046
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:          SPI_Errors_D3   No. Observations:                   23
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -50.165
# Date:                Fri, 21 Jun 2024   AIC                            106.330
# Time:                        20:35:53   BIC                            109.604
# Sample:                    01-01-2024   HQIC                           107.101
#                          - 01-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2075      0.266     -0.781      0.435      -0.728       0.313
# ma.L1         -0.9995     52.112     -0.019      0.985    -103.138     101.139
# sigma2         4.7692    248.239      0.019      0.985    -481.771     491.310
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                 0.58
# Prob(Q):                              0.63   Prob(JB):                         0.75
# Heteroskedasticity (H):               0.89   Skew:                             0.18
# Prob(H) (two-sided):                  0.89   Kurtosis:                         2.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training ARIMA model for High_Low_D4...
# RMSE for High_Low_D4: 1.445869989081319
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            High_Low_D4   No. Observations:                   23
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -47.408
# Date:                Fri, 21 Jun 2024   AIC                            100.815
# Time:                        20:35:54   BIC                            104.088
# Sample:                    01-01-2024   HQIC                           101.586
#                          - 01-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2175      0.277      0.786      0.432      -0.325       0.760
# ma.L1         -0.9361      0.352     -2.663      0.008      -1.625      -0.247
# sigma2         4.0450      2.139      1.891      0.059      -0.147       8.237
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                 0.78
# Prob(Q):                              0.63   Prob(JB):                         0.68
# Heteroskedasticity (H):               0.58   Skew:                             0.40
# Prob(H) (two-sided):                  0.49   Kurtosis:                         2.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np

# Load the data
df = pd.read_csv('updated_worker_defect_details.csv')

# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Set Date as index
df.set_index('Date', inplace=True)

defect_types = ['Run_Off_D1', 'Open_Seam_D2', 'SPI_Errors_D3', 'High_Low_D4']

# Prompt user to select a worker ID
worker_id = input("Enter the Worker ID: ")

# Filter the data for the selected worker ID
worker_data = df[df['Worker_ID'] == worker_id]

if worker_data.empty:
    print(f"No data found for worker {worker_id}.")
else:
    # Plotting time series for each defect type for the selected worker
    plt.figure(figsize=(14, 10))
    for i, defect_type in enumerate(defect_types, 1):
        plt.subplot(len(defect_types), 1, i)
        plt.plot(worker_data.index, worker_data[defect_type], marker='o', linestyle='-', color='red')  # Red color
        plt.title(f'Previous data plot for {defect_type} (Worker {worker_id})')
        plt.xlabel('Date')
        plt.ylabel(f'{defect_type} Count')
        plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Calculate summary statistics for each defect type for the selected worker
    summary_stats = worker_data[defect_types].agg(['mean', 'sum']).transpose()

    # Determine high and low defect types for the selected worker
    high_defect_type = summary_stats.idxmax()['mean']
    low_defect_type = summary_stats.idxmin()['mean']

    print(f"High defect type for worker {worker_id}: {high_defect_type}")
    print(f"Low defect type for worker {worker_id}: {low_defect_type}")

    print()

    # Calculate last week's high and low defect counts for the selected worker
    last_week_data = worker_data.last('7D')
    last_week_summary = last_week_data[defect_types].sum()
    last_week_high_defect_type = last_week_summary.idxmax()
    last_week_low_defect_type = last_week_summary.idxmin()
    last_week_high_defect_count = last_week_summary.max()
    last_week_low_defect_count = last_week_summary.min()

    print(f"Worker {worker_id} - Last week's high defect type: {last_week_high_defect_type} with count: {last_week_high_defect_count}")
    print(f"Worker {worker_id} - Last week's low defect type: {last_week_low_defect_type} with count: {last_week_low_defect_count}")

    print()

    # Train ARIMA models and make forecasts for each defect type for the selected worker
    forecast_steps = 10  # Number of steps to forecast into the future (2 weeks of business days)

    def train_arima_model(data, order=(1, 1, 1), steps=10):
        model = ARIMA(data, order=order)
        model_fit = model.fit()
        forecast = model_fit.forecast(steps=steps)
        return model_fit, forecast

    def calculate_rmse(observed, forecast):
        mse = mean_squared_error(observed, forecast)
        rmse = np.sqrt(mse)
        return rmse

    for defect_type in defect_types:
        print(f"Training ARIMA model for {defect_type} (Worker {worker_id})...")
        model_fit, forecast = train_arima_model(worker_data[defect_type], steps=forecast_steps)

        # Calculate RMSE
        rmse = calculate_rmse(worker_data[defect_type][-forecast_steps:], forecast)
        print(f"RMSE for {defect_type} (Worker {worker_id}): {rmse}")

        # Plotting the results
        plt.figure(figsize=(12, 6))
        plt.plot(worker_data.index, worker_data[defect_type], label='Observed', color='blue')  # Blue color for observed
        future_dates = pd.date_range(start=worker_data.index[-1], periods=forecast_steps + 1, freq='B')[1:]
        plt.plot(future_dates, forecast, label='Forecast', linestyle='--', marker='o', color='purple')  # Purple color for forecast
        plt.title(f'Future forecast for {defect_type} (Worker {worker_id})')
        plt.xlabel('Date')
        plt.ylabel(f'{defect_type} Count')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Print model summary
        print(model_fit.summary())
# Out:
# /var/folders/68/8_7nlx1973v1qqcz0zq5wt8m0000gn/T/ipykernel_989/3125588710.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])
# High defect type for worker W_00001: Run_Off_D1
# Low defect type for worker W_00001: High_Low_D4
#
# Worker W_00001 - Last week's high defect type: Run_Off_D1 with count: 19
# Worker W_00001 - Last week's low defect type: SPI_Errors_D3 with count: 4
#
# Training ARIMA model for Run_Off_D1 (Worker W_00001)...
# RMSE for Run_Off_D1 (Worker W_00001): 1.6896289947158512
# /var/folders/68/8_7nlx1973v1qqcz0zq5wt8m0000gn/T/ipykernel_989/3125588710.py:52: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   last_week_data = worker_data.last('7D')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Run_Off_D1   No. Observations:                   45
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -95.376
# Date:                Fri, 21 Jun 2024   AIC                            196.752
# Time:                        22:30:32   BIC                            202.105
# Sample:                             0   HQIC                           198.737
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1036      0.190     -0.544      0.586      -0.477       0.269
# ma.L1         -0.9057      0.102     -8.850      0.000      -1.106      -0.705
# sigma2         4.2805      1.368      3.130      0.002       1.600       6.961
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.44   Jarque-Bera (JB):                 2.63
# Prob(Q):                              0.51   Prob(JB):                         0.27
# Heteroskedasticity (H):               0.72   Skew:                            -0.01
# Prob(H) (two-sided):                  0.53   Kurtosis:                         1.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training ARIMA model for Open_Seam_D2 (Worker W_00001)...
# RMSE for Open_Seam_D2 (Worker W_00001): 2.0132035845493763
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Open_Seam_D2   No. Observations:                   45
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -95.438
# Date:                Fri, 21 Jun 2024   AIC                            196.876
# Time:                        22:30:33   BIC                            202.229
# Sample:                             0   HQIC                           198.861
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1276      0.173     -0.737      0.461      -0.467       0.212
# ma.L1         -0.9996     15.364     -0.065      0.948     -31.113      29.113
# sigma2         4.0892     62.947      0.065      0.948    -119.285     127.463
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 3.29
# Prob(Q):                              0.84   Prob(JB):                         0.19
# Heteroskedasticity (H):               1.18   Skew:                            -0.17
# Prob(H) (two-sided):                  0.75   Kurtosis:                         1.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for SPI_Errors_D3 (Worker W_00001)...
# RMSE for SPI_Errors_D3 (Worker W_00001): 1.5819857442261682
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:          SPI_Errors_D3   No. Observations:                   45
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -97.623
# Date:                Fri, 21 Jun 2024   AIC                            201.245
# Time:                        22:30:33   BIC                            206.598
# Sample:                             0   HQIC                           203.230
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0343      0.168     -0.204      0.839      -0.364       0.295
# ma.L1         -0.9353      0.144     -6.475      0.000      -1.218      -0.652
# sigma2         4.7156      1.656      2.848      0.004       1.470       7.961
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 2.69
# Prob(Q):                              0.87   Prob(JB):                         0.26
# Heteroskedasticity (H):               0.81   Skew:                             0.44
# Prob(H) (two-sided):                  0.70   Kurtosis:                         2.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training ARIMA model for High_Low_D4 (Worker W_00001)...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# RMSE for High_Low_D4 (Worker W_00001): 2.2525416606411293
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            High_Low_D4   No. Observations:                   45
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -97.161
# Date:                Fri, 21 Jun 2024   AIC                            200.321
# Time:                        22:30:33   BIC                            205.674
# Sample:                             0   HQIC                           202.306
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1037      0.171      0.605      0.545      -0.232       0.440
# ma.L1         -0.9996     12.132     -0.082      0.934     -24.777      22.778
# sigma2         4.4683     54.600      0.082      0.935    -102.547     111.483
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 3.66
# Prob(Q):                              0.91   Prob(JB):                         0.16
# Heteroskedasticity (H):               1.12   Skew:                             0.58
# Prob(H) (two-sided):                  0.84   Kurtosis:                         2.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
